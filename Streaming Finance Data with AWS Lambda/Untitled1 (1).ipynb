# %%
import yfinance as yf
import pandas as pd # data manipulation
import matplotlib.pyplot as plt # main visualization module: matplotlib's pyplot
import seaborn as sns # visualizations' top level. seaborn's style on top of matplotlib
sns.set()
from pandas_datareader import data
from pandas_datareader._utils import RemoteDataError
from datetime import datetime
import json

# %%
List = {"FB","SHOP","BYND","NFLX","PINS","SQ","TTD","OKTA","SNAP","DDOG"}

# %%
A = yf.Ticker("FB").history(period = '1d', interval = '5m')
A
# Out:
#                                  Open        High         Low       Close  \
# Datetime
# 2022-05-13 09:30:00-04:00  192.580002  194.600006  191.580002  192.619995
# 2022-05-13 09:35:00-04:00  192.089996  194.082001  191.279999  194.082001
# 2022-05-13 09:40:00-04:00  193.500000  195.490005  193.500000  195.164993
# 2022-05-13 09:45:00-04:00  194.449997  195.210007  194.149994  194.740005
# 2022-05-13 09:50:00-04:00  195.270004  196.190002  195.130005  196.119705
# ...                               ...         ...         ...         ...
# 2022-05-13 15:40:00-04:00  197.979996  198.470001  197.820007  198.241806
# 2022-05-13 15:45:00-04:00  198.270004  198.490005  197.669998  198.031006
# 2022-05-13 15:50:00-04:00  198.100006  198.300003  197.240005  197.919998
# 2022-05-13 15:55:00-04:00  197.945007  198.789993  197.619995  198.669998
# 2022-05-13 16:00:00-04:00  198.619995  198.619995  198.619995  198.619995
#
#                             Volume  Dividends  Stock Splits
# ...

# %%
yf.Ticker("TSLA").history(period = "1d", interval = "5m")
# Out:
#                                  Open        High         Low       Close  \
# Datetime
# 2022-05-13 09:30:00-04:00  773.479980  774.114990  754.750000  754.750000
# 2022-05-13 09:35:00-04:00  753.000000  764.059998  751.659973  758.309875
# 2022-05-13 09:40:00-04:00  756.500000  766.309998  756.159973  760.932190
# 2022-05-13 09:45:00-04:00  760.375000  764.549988  756.520020  760.479980
# 2022-05-13 09:50:00-04:00  764.000000  767.000000  761.364014  766.741821
# ...                               ...         ...         ...         ...
# 2022-05-13 15:40:00-04:00  767.679993  769.299988  767.000000  767.099976
# 2022-05-13 15:45:00-04:00  767.349976  769.419983  765.349976  767.484985
# 2022-05-13 15:50:00-04:00  767.200012  768.500000  762.320007  766.330017
# 2022-05-13 15:55:00-04:00  766.510010  770.159973  764.770020  769.679993
# 2022-05-13 16:00:00-04:00  769.590027  769.590027  769.590027  769.590027
#
#                             Volume  Dividends  Stock Splits
# ...

# %%
A = A["Open"][0]
print(A)
type(A)
# Out:
# 192.5800018310547
# numpy.float64

# %%
for i in List:
    df = yf.Ticker(i).history(period = '1d', interval = '5m')
    df = df.drop(['Open','Close', 'Volume','Dividends','Stock Splits'], axis=1)
    df.insert(2,'name',i)
    out = df.to_json(orient='records')[1:-1].replace('},{', '} {')
    print(out)
# Out:
# {"High":93.6200027466,"Low":90.4000015259,"name":"OKTA"} {"High":94.3199996948,"Low":92.6299972534,"name":"OKTA"} {"High":94.9100036621,"Low":92.7549972534,"name":"OKTA"} {"High":95.7900009155,"Low":94.6200027466,"name":"OKTA"} {"High":96.0,"Low":95.3199996948,"name":"OKTA"} {"High":96.2099990845,"Low":94.6200027466,"name":"OKTA"} {"High":95.9449996948,"Low":94.8799972534,"name":"OKTA"} {"High":95.9700012207,"Low":95.1699981689,"name":"OKTA"} {"High":95.6500015259,"Low":94.7300033569,"name":"OKTA"} {"High":95.9100036621,"Low":94.8899993896,"name":"OKTA"} {"High":96.0,"Low":95.25,"name":"OKTA"} {"High":96.3099975586,"Low":95.4300003052,"name":"OKTA"} {"High":95.9599990845,"Low":95.1299972534,"name":"OKTA"} {"High":96.6200027466,"Low":95.75,"name":"OKTA"} {"High":97.0400009155,"Low":95.5599975586,"name":"OKTA"} {"High":96.3399963379,"Low":95.0999984741,"name":"OKTA"} {"High":96.5599975586,"Low":95.9100036621,"name":"OKTA"} {"High":96.6800003052,"Low":95.7399978638,"name":"OKTA"} {"High
# ...

# %%
for i in List:
    df = yf.Ticker(i).history(period = '1d', interval = '5m')
    df = df.drop(['Open','Close', 'Volume','Dividends','Stock Splits'], axis=1)
    df.insert(2,'name',i)
    df.reset_index(inplace=True)
    df = df.rename(columns = {'Datetime':'ts'})
    print(df)
    #out = df.to_json(orient='records')[1:-1].replace('},{', '} {')
    #print(out)
# Out:
#                           ts       High        Low  name
# 0  2022-05-13 09:30:00-04:00  93.620003  90.400002  OKTA
# 1  2022-05-13 09:35:00-04:00  94.320000  92.629997  OKTA
# 2  2022-05-13 09:40:00-04:00  94.910004  92.754997  OKTA
# 3  2022-05-13 09:45:00-04:00  95.790001  94.620003  OKTA
# 4  2022-05-13 09:50:00-04:00  96.000000  95.320000  OKTA
# ..                       ...        ...        ...   ...
# 74 2022-05-13 15:40:00-04:00  98.070000  97.510002  OKTA
# 75 2022-05-13 15:45:00-04:00  98.035004  97.614998  OKTA
# 76 2022-05-13 15:50:00-04:00  98.290001  97.440002  OKTA
# 77 2022-05-13 15:55:00-04:00  97.809998  97.425003  OKTA
# 78 2022-05-13 16:00:00-04:00  97.699997  97.699997  OKTA
#
# [79 rows x 4 columns]
#                           ts       High        Low name
# 0  2022-05-13 09:30:00-04:00  48.450001  46.660000  TTD
# 1  2022-05-13 09:35:00-04:00  48.500000  47.000000  TTD
# 2  2022-05-13 09:40:00-04:00  49.419998  48.230000  TTD
# ...

# %%
for i in List:
    df = yf.Ticker(i).history(period = '1d', interval = '5m')
    df = df.drop(['Open','Close', 'Volume','Dividends','Stock Splits'], axis=1)
    df.insert(2,'name',i)
    df.reset_index(inplace=True)
    df = df.rename(columns = {'Datetime':'ts'})
    out = df.to_json(orient='records')[1:-1].replace('},{', '} {')+"\n"
    print(out)
# Out:
# {"ts":1652448600000,"High":21.0699996948,"Low":20.2299995422,"name":"PINS"} {"ts":1652448900000,"High":20.8099994659,"Low":20.5100002289,"name":"PINS"} {"ts":1652449200000,"High":20.8899993896,"Low":20.5100002289,"name":"PINS"} {"ts":1652449500000,"High":20.9300003052,"Low":20.75,"name":"PINS"} {"ts":1652449800000,"High":21.0900001526,"Low":20.8199996948,"name":"PINS"} {"ts":1652450100000,"High":21.0699996948,"Low":20.8099994659,"name":"PINS"} {"ts":1652450400000,"High":21.0550003052,"Low":20.8500003815,"name":"PINS"} {"ts":1652450700000,"High":21.2099990845,"Low":21.0300006866,"name":"PINS"} {"ts":1652451000000,"High":21.25,"Low":21.125,"name":"PINS"} {"ts":1652451300000,"High":21.1599998474,"Low":21.0300006866,"name":"PINS"} {"ts":1652451600000,"High":21.2749996185,"Low":21.0249996185,"name":"PINS"} {"ts":1652451900000,"High":21.3500003815,"Low":21.1900005341,"name":"PINS"} {"ts":1652452200000,"High":21.2700004578,"Low":21.1009998322,"name":"PINS"} {"ts":1652452500000,"High":21.270
# ...

# %%
def get_data(i):
    df = yf.Ticker(i).history(period = '1d', interval = '5m')
    df = df.drop(['Open','Close', 'Volume','Dividends','Stock Splits'], axis=1)
    df.insert(2,'name',i)
    return df


for i in List:
        data = json.dumps(get_data(i))+"\n"
        print(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16144/1430997247.py in <module>
#       7
#       8 for i in List:
# ----> 9         data = json.dumps(get_data(i))+"\n"
#      10         print(data)
#
# ~\anaconda3\lib\json\__init__.py in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     229         cls is None and indent is None and separators is None and
#     230         default is None and not sort_keys and not kw):
# --> 231         return _default_encoder.encode(obj)
#     232     if cls is None:
#     233         cls = JSONEncoder
#
# ~\anaconda3\lib\json\encoder.py in encode(self, o)
#     197         # exceptions aren't as detailed.  The list call should be roughly
#     198         # equivalent to the PySequence_Fast that ''.join() would do.
# ...

# %%
#for i in List:
df = yf.Ticker("TSLA").history(period = '1d', interval = '5m')
df = df.drop(['Open','Close', 'Volume','Dividends','Stock Splits'], axis=1)
df.insert(2,'name',"TSLA")
df.reset_index(inplace=True)
df = df.rename(columns = {'Datetime':'ts'})
out = df.to_json(orient='records')[1:-1].replace('},{', '} {')+"\n"
print(out)
# Out:
# {"ts":1652448600000,"High":774.1149902344,"Low":754.75,"name":"TSLA"} {"ts":1652448900000,"High":764.0599975586,"Low":751.6599731445,"name":"TSLA"} {"ts":1652449200000,"High":766.3099975586,"Low":756.1599731445,"name":"TSLA"} {"ts":1652449500000,"High":764.549987793,"Low":756.5200195312,"name":"TSLA"} {"ts":1652449800000,"High":767.0,"Low":761.3640136719,"name":"TSLA"} {"ts":1652450100000,"High":772.7550048828,"Low":763.0842895508,"name":"TSLA"} {"ts":1652450400000,"High":774.3699951172,"Low":766.8400268555,"name":"TSLA"} {"ts":1652450700000,"High":771.6400146484,"Low":765.200012207,"name":"TSLA"} {"ts":1652451000000,"High":769.5,"Low":760.9899902344,"name":"TSLA"} {"ts":1652451300000,"High":763.924987793,"Low":760.1900024414,"name":"TSLA"} {"ts":1652451600000,"High":769.5900268555,"Low":762.5867919922,"name":"TSLA"} {"ts":1652451900000,"High":772.7498779297,"Low":768.3120727539,"name":"TSLA"} {"ts":1652452200000,"High":774.2199707031,"Low":765.5,"name":"TSLA"} {"ts":1652452500000,"H
# ...

# %%
for i in List:
    df = yf.Ticker(i).history(period = '1d', interval = '5m')
    df = df.drop(['Open','Close', 'Volume','Dividends','Stock Splits'], axis=1)
    df.insert(2,'name',i)
    df.reset_index(inplace=True)
    df = df.rename(columns = {'Datetime':'ts'})
    df['ts'] = df['ts'].astype(str)
    out = df.to_json(orient='records')[1:-1].replace('},{', '} {')+"\n"
    print("James" + "\n")
    print(out)
    
    #df['datetime'] = df['datetime'].astype(str)
# Out:
# James
#
# ...

# %%
for i in List:
    df = yf.Ticker(i).history(period = '1d', interval = '5m')
    df = df.drop(['Open','Close', 'Volume','Dividends','Stock Splits'], axis=1)
    df.insert(2,'name',i)
    df.reset_index(inplace=True)
    df = df.rename(columns = {'Datetime':'ts'})
    df['ts'] = df['ts'].astype(str)
    out = df.to_json(orient='records')[1:-1].replace('},{', '} {')+"\n"
    print(out)
    
    #df['datetime'] = df['datetime'].astype(str)
# Out:
# {"ts":"2022-05-13 09:30:00-04:00","High":180.6699981689,"Low":176.7200927734,"name":"NFLX"} {"ts":"2022-05-13 09:35:00-04:00","High":179.0249938965,"Low":176.9924926758,"name":"NFLX"} {"ts":"2022-05-13 09:40:00-04:00","High":180.2998962402,"Low":177.9600067139,"name":"NFLX"} {"ts":"2022-05-13 09:45:00-04:00","High":180.2700042725,"Low":179.0,"name":"NFLX"} {"ts":"2022-05-13 09:50:00-04:00","High":181.1900024414,"Low":179.8300018311,"name":"NFLX"} {"ts":"2022-05-13 09:55:00-04:00","High":181.4250030518,"Low":178.9100036621,"name":"NFLX"} {"ts":"2022-05-13 10:00:00-04:00","High":181.1799926758,"Low":179.2599945068,"name":"NFLX"} {"ts":"2022-05-13 10:05:00-04:00","High":181.8000030518,"Low":180.0,"name":"NFLX"} {"ts":"2022-05-13 10:10:00-04:00","High":181.3899993896,"Low":179.7599945068,"name":"NFLX"} {"ts":"2022-05-13 10:15:00-04:00","High":180.3500061035,"Low":179.5399932861,"name":"NFLX"} {"ts":"2022-05-13 10:20:00-04:00","High":180.9700012207,"Low":179.3325042725,"name":"NFLX"} {"ts
# ...

# %%
for i in List:
    df = yf.Ticker(i).history(period = '1d', interval = '5m')
    df = df.drop(['Open','Close', 'Volume','Dividends','Stock Splits'], axis=1)
    df.insert(2,'name',i)
    df.reset_index(inplace=True)
    df = df.rename(columns = {'Datetime':'ts'})
    df['ts'] = df['ts'].astype(str)
    out = df.to_json(orient='records')[0:-1].replace('},{', '} {')+"\n"
    parsed = json.loads(out)
    print(parsed)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22864/3863141128.py in <module>
#       7     df['ts'] = df['ts'].astype(str)
#       8     out = df.to_json(orient='records')[0:-1].replace('},{', '} {')+"\n"
# ----> 9     parsed = json.loads(out)
#      10     print(parsed)
#
# ~\anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#     348         cls = JSONDecoder
#
# ~\anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
# ...

# %%
for i in List:
    df = yf.Ticker(i).history(period = '1d', interval = '5m')
    df = df.drop(['Open','Close', 'Volume','Dividends','Stock Splits'], axis=1)
    df.insert(2,'name',i)
    df.reset_index(inplace=True)
    df = df.rename(columns = {'Datetime':'ts'})
    df['ts'] = df['ts'].astype(str)
    out = df.to_json(orient='split')[0:-1].replace('},{', '} {')+"\n"
    parsed = json.loads(out)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22864/3141605009.py in <module>
#       7     df['ts'] = df['ts'].astype(str)
#       8     out = df.to_json(orient='split')[0:-1].replace('},{', '} {')+"\n"
# ----> 9     parsed = json.loads(out)
#
# ~\anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#     348         cls = JSONDecoder
#
# ~\anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
# ...

# %%
for i in List:
    df = yf.Ticker(i).history(period = '1d', interval = '5m')
    df = df.drop(['Open','Close', 'Volume','Dividends','Stock Splits'], axis=1)
    df.insert(2,'name',i)
    df.reset_index(inplace=True)
    df = df.rename(columns = {'Datetime':'ts'})
    df['ts'] = df['ts'].astype(str)
    df1 = df.to_dict()
    print(df1)
# Out:
# {'ts': {0: '2022-05-13 09:30:00-04:00', 1: '2022-05-13 09:35:00-04:00', 2: '2022-05-13 09:40:00-04:00', 3: '2022-05-13 09:45:00-04:00', 4: '2022-05-13 09:50:00-04:00', 5: '2022-05-13 09:55:00-04:00', 6: '2022-05-13 10:00:00-04:00', 7: '2022-05-13 10:05:00-04:00', 8: '2022-05-13 10:10:00-04:00', 9: '2022-05-13 10:15:00-04:00', 10: '2022-05-13 10:20:00-04:00', 11: '2022-05-13 10:25:00-04:00', 12: '2022-05-13 10:30:00-04:00', 13: '2022-05-13 10:35:00-04:00', 14: '2022-05-13 10:40:00-04:00', 15: '2022-05-13 10:45:00-04:00', 16: '2022-05-13 10:50:00-04:00', 17: '2022-05-13 10:55:00-04:00', 18: '2022-05-13 11:00:00-04:00', 19: '2022-05-13 11:05:00-04:00', 20: '2022-05-13 11:10:00-04:00', 21: '2022-05-13 11:15:00-04:00', 22: '2022-05-13 11:20:00-04:00', 23: '2022-05-13 11:25:00-04:00', 24: '2022-05-13 11:30:00-04:00', 25: '2022-05-13 11:35:00-04:00', 26: '2022-05-13 11:40:00-04:00', 27: '2022-05-13 11:45:00-04:00', 28: '2022-05-13 11:50:00-04:00', 29: '2022-05-13 11:55:00-04:00', 30: '2022-
# ...

# %%
for i in List:
    df = yf.Ticker(i).history(period = '1d', interval = '5m')
    df = df.drop(['Open','Close', 'Volume','Dividends','Stock Splits'], axis=1)
    df.insert(2,'name',i)
    df.reset_index(inplace=True)
    df = df.rename(columns = {'Datetime':'ts'})
    df['ts'] = df['ts'].astype(str)
    x=0
    while x < 79:
        x=0
        dataset = vars(df.loc[x])
        x+=1
        data = json.dumps(dataset)+"\n"
        print(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22864/1630067297.py in <module>
#      11         dataset = vars(df.loc[x])
#      12         x+=1
# ---> 13         data = json.dumps(dataset)+"\n"
#      14         print(data)
#      15
#
# ~\anaconda3\lib\json\__init__.py in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     229         cls is None and indent is None and separators is None and
#     230         default is None and not sort_keys and not kw):
# --> 231         return _default_encoder.encode(obj)
#     232     if cls is None:
#     233         cls = JSONEncoder
#
# ~\anaconda3\lib\json\encoder.py in encode(self, o)
#     197         # exceptions aren't as detailed.  The list call should be roughly
# ...

# %%
df
# Out:
#                            ts        High         Low  name
# 0   2022-05-13 09:30:00-04:00  104.084900  102.254997  DDOG
# 1   2022-05-13 09:35:00-04:00  103.514999  101.610001  DDOG
# 2   2022-05-13 09:40:00-04:00  104.610001  101.972504  DDOG
# 3   2022-05-13 09:45:00-04:00  105.050003  104.019997  DDOG
# 4   2022-05-13 09:50:00-04:00  106.220001  104.769997  DDOG
# ..                        ...         ...         ...   ...
# 74  2022-05-13 15:40:00-04:00  109.184998  108.639999  DDOG
# 75  2022-05-13 15:45:00-04:00  108.989899  108.470001  DDOG
# 76  2022-05-13 15:50:00-04:00  109.000000  108.129997  DDOG
# 77  2022-05-13 15:55:00-04:00  108.959999  108.379997  DDOG
# 78  2022-05-13 16:00:00-04:00  108.860001  108.860001  DDOG
#
# [79 rows x 4 columns]

# %%
#df.at[0,"ts"]
# Out:
# '2022-05-13 09:30:00-04:00'

# %%
m=0
x = vars(df.loc[m])
type(x)
print(x)
# Out:
# {'_is_copy': <weakref at 0x000001B8D2C82720; to 'DataFrame' at 0x000001B8D0957BE0>, '_mgr': SingleBlockManager
# Items: Index(['ts', 'High', 'Low', 'name'], dtype='object')
# ObjectBlock: 4 dtype: object, '_item_cache': {}, '_attrs': {}, '_flags': <Flags(allows_duplicate_labels=True)>, '_name': 0, '_index': Index(['ts', 'High', 'Low', 'name'], dtype='object')}

# %%
b = vars(x)
print(b)
type(b)
# Out:
# {'_is_copy': <weakref at 0x000001B8D2C82720; to 'DataFrame' at 0x000001B8D0957BE0>, '_mgr': SingleBlockManager
# Items: Index(['ts', 'High', 'Low', 'name'], dtype='object')
# ObjectBlock: 4 dtype: object, '_item_cache': {}, '_attrs': {}, '_flags': <Flags(allows_duplicate_labels=True)>, '_name': 1, '_index': Index(['ts', 'High', 'Low', 'name'], dtype='object')}
# dict
